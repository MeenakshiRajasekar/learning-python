# %% [markdown]
# # Rock paper scissor game

# %%
import random
def rps_game():
    game_choice = ["rock", "paper", "scissor"]
    while True:
        user_input = int(input("Enter your game choice 0 for Rock, 1 for Paper , 2 for Scissor : "))
        if(user_input>=3):
            print("Invalid input")
        else:
            print(game_choice[user_input])
            comp_input = random.randInt(0,2)
            print(game_choice[comp_input])
            if(user_input == comp_input):
                print("Draw")
            elif(user_input == 0 and comp_input ==2):
                print("you won")
            elif(comp_input == 0 and user_input ==2):
                print("you lose")
            elif(user_input > comp_input):
                print("you won")
            else:
                print("you lose")
            next_attempt = input("Can we continue the game (y/n) :")
            if next_attempt.lower() != y:
                break

# %%
rps_game()
# Out:
# Enter your game choice 0 for Rock, 1 for Paper , 2 for Scissor :  9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 rps_game()
#
# Cell In[5], line 6, in rps_game()
#       4 while True:
#       5     user_input = int(input("Enter your game choice 0 for Rock, 1 for Paper , 2 for Scissor : "))
# ----> 6     print(game_choice(user_input))
#       7     comp_input = random.randInt(0,2)
#       8     print(game_choice(comp_input))
#
# TypeError: 'list' object is not callable
